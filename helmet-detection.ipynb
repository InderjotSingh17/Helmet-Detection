# %%
import os
print(os.listdir('/kaggle/input/datasets/inderjotsingh2007/helmet-detection-dataset'))
# Out:
# ['README.roboflow.txt', 'data.yaml', 'train']

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 42.7 MB/s eta 0:00:00
# ...

# %%
import yaml

data = {
    'train': '/kaggle/input/datasets/inderjotsingh2007/helmet-detection-dataset/train/images',
    'val': '/kaggle/input/datasets/inderjotsingh2007/helmet-detection-dataset/train/images',
    'nc': 2,
    'names': ['Helmet', 'NoHelmet']
}

with open('/kaggle/working/data.yaml', 'w') as f:
    yaml.dump(data, f)

# %%
import os

print(os.listdir('/kaggle/input/datasets/inderjotsingh2007/helmet-detection-dataset/train'))
# Out:
# ['labels', 'images']

# %%
from ultralytics import YOLO
model=YOLO('yolov8n.pt')
model.train(
    data='/kaggle/working/data.yaml',
    epochs=20,
    imgsz=640
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.39 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
from ultralytics import YOLO

model = YOLO('/kaggle/working/runs/detect/train/weights/best.pt')

results = model.predict(
    source='/kaggle/input/datasets/inderjotsingh2007/helmet-detection-dataset/train/images',
    save=True
)
# Out:
# image 1/235 /kaggle/input/datasets/inderjotsingh2007/helmet-detection-dataset/train/images/BikesHelmets370_png.rf.nreDteBvNmYnZ6q9JTVs.png: 480x640 2 Helmets, 149.6ms
# image 2/235 /kaggle/input/datasets/inderjotsingh2007/helmet-detection-dataset/train/images/BikesHelmets372_png.rf.nNjQkwuAbOxs3Ch6kvtW.png: 448x640 2 NoHelmets, 136.2ms
# image 3/235 /kaggle/input/datasets/inderjotsingh2007/helmet-detection-dataset/train/images/BikesHelmets374_png.rf.wzcsXYoRNJWgzPFRASUK.png: 512x640 1 Helmet, 143.0ms
# image 4/235 /kaggle/input/datasets/inderjotsingh2007/helmet-detection-dataset/train/images/BikesHelmets376_png.rf.ywpCsTpT41XipEdE6M74.png: 480x640 1 NoHelmet, 107.4ms
# image 5/235 /kaggle/input/datasets/inderjotsingh2007/helmet-detection-dataset/train/images/BikesHelmets379_png.rf.IDicxyyQYWm5984sgpbU.png: 384x640 1 NoHelmet, 157.2ms
# ...
